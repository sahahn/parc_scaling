# %%
from nilearn.plotting import plot_surf_stat_map, plot_surf_roi
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/sage/anaconda3/envs/home/lib/python3.8/site-packages/nilearn/datasets/__init__.py:87: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
def rh(mode='curv'):

    data_loc = '../data/abcd_structural/' + mode + '/INV0B0HVEYX.npy'
    data = np.load(data_loc)
    rh_data = data[len(data) // 2:]
    
    return rh_data

def rh_rois(name='schaefer_100'):
            
    data_loc = '../parcels/' + name + '.npy'
    data = np.load(data_loc)
    rh_data = data[len(data) // 2:]
    
    return rh_data

rh_mesh = '/home/sage/neurotools/neurotools/data/32k_fs_LR/surf/rh.inflated'

# %%
plot_surf_stat_map(rh_mesh, rh('curv'),
                   hemi='right', colorbar=False,
                   cmap='blue_orange')

plt.title('Curvature', fontsize=28)
plt.savefig('Figures/curv.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
plot_surf_stat_map(rh_mesh, rh('thick'),
                   hemi='right', colorbar=False,
                   cmap='ocean_hot')

plt.title('Thickness', fontsize=28)
plt.savefig('Figures/thick.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
plot_surf_stat_map(rh_mesh, rh('sulc'),
                   hemi='right', colorbar=False,
                   cmap='cold_hot')

plt.title('Sulcal Depth', fontsize=28)
plt.savefig('Figures/sulc.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
plot_surf_stat_map(rh_mesh, rh('myelin'),
                   hemi='right', colorbar=False, symmetric_cbar=False,
                   cmap='hot_black_bone_r', vmax=6)

plt.title('Myelination', fontsize=28)
plt.savefig('Figures/myelin.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
plot_surf_roi(rh_mesh, rh_rois('schaefer_500'), hemi='right', cmap='prism')
plt.title('Existing', fontsize=28)
plt.savefig('Figures/e1.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('desikan_dlab'), hemi='right', cmap='prism')
plt.savefig('Figures/e2.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('hcp_mmp'), hemi='right', cmap='prism')
plt.savefig('Figures/e3.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
plot_surf_roi(rh_mesh, rh_rois('icosahedron-42_dlab'), hemi='right', cmap='prism')
plt.title('Icosahedron', fontsize=28)
plt.savefig('Figures/i1.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('icosahedron-362_dlab'), hemi='right', cmap='prism')
plt.savefig('Figures/i2.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('icosahedron-1002_dlab'), hemi='right', cmap='prism')
plt.savefig('Figures/i3.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
plot_surf_roi(rh_mesh, rh_rois('random_100_0'), hemi='right', cmap='prism')
plt.title('Random', fontsize=28)
plt.savefig('Figures/random100.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('random_500_0'), hemi='right', cmap='prism')
plt.savefig('Figures/random500.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('random_2000_0'), hemi='right', cmap='prism')
plt.savefig('Figures/random2000.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
plot_surf_roi(rh_mesh, rh_rois('random_100_1'), hemi='right', cmap='prism')
plt.savefig('Figures/random100_1.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('random_100_2'), hemi='right', cmap='prism')
plt.savefig('Figures/random100_2.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('random_100_3'), hemi='right', cmap='prism')
plt.savefig('Figures/random100_3.png', dpi=300, transparent=True, bbox_inches='tight')

# %%
plot_surf_roi(rh_mesh, rh_rois('random_100_0'), hemi='right', cmap='prism')
plt.savefig('Figures/100.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('random_200_0'), hemi='right', cmap='prism')
plt.savefig('Figures/200.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('random_300_0'), hemi='right', cmap='prism')
plt.savefig('Figures/300.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('random_400_0'), hemi='right', cmap='prism')
plt.savefig('Figures/400.png', dpi=300, transparent=True, bbox_inches='tight')

plot_surf_roi(rh_mesh, rh_rois('random_500_0'), hemi='right', cmap='prism')
plt.savefig('Figures/500.png', dpi=300, transparent=True, bbox_inches='tight')
